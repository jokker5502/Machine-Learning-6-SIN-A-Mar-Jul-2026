# %%
#Imports necessary the necesary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as ptl 

# %matplotlib inline

# %%
#Import the csv, to obtain data
unemploymment = pd.read_csv('/workspaces/Machine-Learning-6-SIN-A-Mar-Jul-2026/data/country_total.csv')

# %%
#Type of the dataframe
type(unemploymment)
# Out:
# pandas.DataFrame

# %%
#Obtain de first 5 rows
unemploymment.head()

# %%
#Obtain de size of the dataframe
unemploymment.shape

# %%
#Obtain the name of the colums
unemploymment.columns

# %%
#Types of data on the dataframe
unemploymment.dtypes

# %%
#Summary of the table
unemploymment.describe

# %%
#read the last 4 data
my_list = ['a','b','c','d','e','f']
my_list[2:]
# Out:
#    0
# 2  c
# 3  d
# 4  e
# 5  f

# %%
import pandas as pd
country = pd.read_csv('/workspaces/Machine-Learning-6-SIN-A-Mar-Jul-2026/data/countries.csv')
print("Primeras filas:")
print(unemploymment.head())

print("Columnas:")
print(unemploymment.columns)

print("Shape (filas, columnas):")
print(unemploymment.shape)

print("Información del dataset:")
print(unemploymment.info())

print("Estadísticas descriptivas:")
print(unemploymment.describe())

print("Valores nulos por columna:")
print(unemploymment.isnull().sum())
# Out:
# Primeras filas:
#   country google_country_code country_group   name_en   name_fr     name_de  \
# 0      at                  AT            eu   Austria  Autriche  Österreich
# 1      be                  BE            eu   Belgium  Belgique     Belgien
# 2      bg                  BG            eu  Bulgaria  Bulgarie   Bulgarien
# 3      hr                  HR        non-eu   Croatia   Croatie    Kroatien
# 4      cy                  CY            eu    Cyprus    Chypre      Zypern
#
#     latitude  longitude
# 0  47.696554  13.345980
# 1  50.501045   4.476674
# 2  42.725674  25.482322
# 3  44.746643  15.340844
# 4  35.129141  33.428682
# Columnas:
# Index(['country', 'google_country_code', 'country_group', 'name_en', 'name_fr',
#        'name_de', 'latitude', 'longitude'],
#       dtype='str')
# Shape (filas, columnas):
# (30, 8)
# Información del dataset:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
# ...

# %%
#Search by file on that column
country.loc[3, 'country_group']
# Out:
# 'non-eu'

# %%
#From the 0 to the 4 all the columns
country.loc[:4,:]
# Out:
#   country google_country_code country_group   name_en   name_fr     name_de  \
# 0      at                  AT            eu   Austria  Autriche  Österreich
# 1      be                  BE            eu   Belgium  Belgique     Belgien
# 2      bg                  BG            eu  Bulgaria  Bulgarie   Bulgarien
# 3      hr                  HR        non-eu   Croatia   Croatie    Kroatien
# 4      cy                  CY            eu    Cyprus    Chypre      Zypern
#
#     latitude  longitude
# 0  47.696554  13.345980
# 1  50.501045   4.476674
# 2  42.725674  25.482322
# 3  44.746643  15.340844
# 4  35.129141  33.428682

# %%
#All the rows from 4 columns
country.iloc[:,:4]
# Out:
#    country google_country_code country_group  \
# 0       at                  AT            eu
# 1       be                  BE            eu
# 2       bg                  BG            eu
# 3       hr                  HR        non-eu
# 4       cy                  CY            eu
# 5       cz                  CZ            eu
# 6       dk                  DK            eu
# 7       ee                  EE            eu
# 8       fi                  FI            eu
# 9       fr                  FR            eu
# 10      de                  DE            eu
# 11      gr                  GR            eu
# 12      hu                  HU            eu
# 13      ie                  IE            eu
# 14      it                  IT            eu
# 15      lv                  LV            eu
# 16      lt                  LT            eu
# 17      lu                  LU            eu
# 18      mt                  MT            eu
# 19      nl                  NL            eu
# ...

# %%
#Filtered by the rows we want
test = country.loc[20:25, :]
test
# Out:
#    country google_country_code country_group   name_en    name_fr    name_de  \
# 20      no                  NO        non-eu    Norway    Norvège   Norwegen
# 21      pl                  PL            eu    Poland    Pologne      Polen
# 22      pt                  PT            eu  Portugal   Portugal   Portugal
# 23      ro                  RO            eu   Romania   Roumanie   Rumänien
# 24      sk                  SK            eu  Slovakia  Slovaquie   Slowakei
# 25      si                  SI            eu  Slovenia   Slovénie  Slowenien
#
#      latitude  longitude
# 20  64.556460  12.665766
# 21  51.918907  19.134334
# 22  39.558069  -7.844941
# 23  45.942611  24.990152
# 24  48.672644  19.700032
# 25  46.149259  14.986617

# %%
#filtered by non-eu
test[test['country_group'] == 'non-eu']
# Out:
#    country google_country_code country_group name_en  name_fr   name_de  \
# 20      no                  NO        non-eu  Norway  Norvège  Norwegen
#
#     latitude  longitude
# 20  64.55646  12.665766

# %%
#Filter by the longited > 25
country[country['longitude'] > 25]
# Out:
#    country google_country_code country_group   name_en   name_fr    name_de  \
# 2       bg                  BG            eu  Bulgaria  Bulgarie  Bulgarien
# 4       cy                  CY            eu    Cyprus    Chypre     Zypern
# 7       ee                  EE            eu   Estonia   Estonie    Estland
# 8       fi                  FI            eu   Finland  Finlande   Finnland
# 28      tr                  TR        non-eu    Turkey   Turquie     Türkei
#
#      latitude  longitude
# 2   42.725674  25.482322
# 4   35.129141  33.428682
# 7   58.592469  25.806950
# 8   64.950159  26.067564
# 28  38.952942  35.439795
